# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # 1. Introducción
#
# El servicio de telefonía virtual CallMeMaybe está en proceso de desarrollar una innovadora función diseñada para proporcionar a los supervisores información detallada sobre los operadores menos eficaces. Un operador se considera ineficaz si presenta una gran cantidad de llamadas entrantes perdidas (internas y externas) y un tiempo de espera prolongado para las llamadas entrantes. Además, en los casos en los que se espera que un operador realice llamadas salientes, un número reducido de estas también se considera un signo de ineficacia.
#
# Para cumplir con este objetivo, se llevarán a cabo los siguientes pasos:
#
# Realizar un análisis exploratorio de datos.
#
# Identificar operadores ineficaces.
#
# Probar las hipótesis estadísticas.
#
# Este enfoque permitirá optimizar el rendimiento del servicio y asegurar que los supervisores dispongan de las herramientas necesarias para mejorar la eficacia operativa.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente introducción. Proporciona un contexto claro y detallado sobre el objetivo del proyecto y los pasos a seguir. Esto establece una buena base para el análisis posterior. Continúa estructurando tus proyectos de esta manera.
#
# </div>

# %% [markdown]
# Presentacion PDF
# https://drive.google.com/file/d/1Rt6pqT6TrwNM4EOSp-8UnzCei6nhp1IM/view?usp=sharing
#
# Dashboard 1
# https://public.tableau.com/app/profile/clara.isabel.arredondo.razo/viz/Dash_1_Proyecto_Final/Dashboard2?publish=yes
#
# Dashboard 2
# https://public.tableau.com/app/profile/clara.isabel.arredondo.razo/viz/Dash_2_Proyecto_Final/Dashboard3?publish=yes

# %% [markdown]
# ### **Dashboard 1: Llamadas Entrantes y Salientes**
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - El uso de un gráfico de pastel es efectivo para mostrar la proporción entre las llamadas entrantes y salientes, ofreciendo una visión rápida y clara del desglose. Además, el gráfico de barras complementa bien al mostrar la duración de las llamadas agrupadas. Ambos gráficos son útiles para obtener información general del comportamiento de las llamadas. ¡Buen trabajo en incluir etiquetas para facilitar la interpretación!
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Aunque el gráfico de pastel es visualmente atractivo, sería útil complementar esta visualización con porcentajes adicionales o una tabla para destacar las cifras totales en contexto. Además, el gráfico de barras parece estar sesgado hacia valores pequeños, lo que podría mejorar con un cambio en la escala o la adición de más detalles para interpretar valores altos en la distribución.
# </div>
#
# ---
#
# ### **Dashboard 2: Llamadas por Día**
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - Este dashboard destaca por su claridad al mostrar el desglose entre llamadas internas y externas con un gráfico de pastel, y la evolución de las llamadas diarias en un gráfico de barras. El nivel de detalle y la segmentación son útiles para identificar tendencias a lo largo del tiempo, y la inclusión de filtros hace que el dashboard sea interactivo y flexible.
# </div>

# %% [markdown]
# # 2. Objetivo
#
# Desarrollar una función para el servicio de telefonía virtual CallMeMaybe que permita a los supervisores identificar y evaluar la eficacia de los operadores. Esto se logrará a través de un análisis exploratorio de datos, la identificación de operadores ineficaces basados en métricas clave de rendimiento, y la prueba de hipótesis estadísticas. El objetivo final es optimizar el rendimiento operativo y mejorar la calidad del servicio al cliente mediante la implementación de herramientas que proporcionen información detallada y accionable sobre los operadores.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - El objetivo está bien definido y alineado con el problema descrito en la introducción. La descripción de los pasos para alcanzarlo muestra una buena planificación. ¡Buen trabajo en esta sección!
#
# </div>

# %% [markdown]
# # 3.  Preprocesamiento de datos

# %%
# Importación de librerias
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import pearsonr
from scipy.stats import ttest_ind

# %%
# Lectura del dataset
telecom_data = pd.read_csv(
    "c:/Users/cary_/OneDrive/Escritorio/Data analyst/Sprint 14/telecom_clients_us.csv", sep=",")

clients_data = pd.read_csv(
    "c:/Users/cary_/OneDrive/Escritorio/Data analyst/Sprint 14/telecom_dataset_us.csv", sep=",")

# %%
# Estudia tipo de datos del dataset
clients_data.info()
print("\n")
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53902 entries, 0 to 53901
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              53902 non-null  int64
#  1   date                 53902 non-null  object
#  2   direction            53902 non-null  object
#  3   internal             53785 non-null  object
#  4   operator_id          45730 non-null  float64
#  5   is_missed_call       53902 non-null  bool
#  6   calls_count          53902 non-null  int64
#  7   call_duration        53902 non-null  int64
#  8   total_call_duration  53902 non-null  int64
# dtypes: bool(1), float64(1), int64(4), object(3)
# memory usage: 3.3+ MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      732 non-null    int64
# ...

# %% [markdown]
# Con la información observada en los datasets, se puede notar que algunas columnas no tienen los tipos de datos correctos. Lo primero será revisar los valores duplicados y ausentes para poder hacer las conversiones a los tipos de datos necesarios. A continuación, se usará una función que me ayudará a convertir algunos tipos de datos y reducir el tamaño de la memoria usada por ambos datasets.

# %%
# Revisar si existe algún valor duplicado
print(f'Duplicados totales para clients_data: {clients_data.duplicated().sum()}')
print(f'Duplicados totales para telecom_data: {telecom_data.duplicated().sum()}')
print("\n")

# Borrar valores duplicados
clients_data = clients_data.drop_duplicates().reset_index(drop=True)
# Out:
# Duplicados totales para clients_data: 4900
# Duplicados totales para telecom_data: 0

# %% [markdown]
# En esta sección, los resultados muestran que existen valores ausentes en las columnas internal y operator_id. Dado que la columna internal solo contiene valores como True y False, utilizaré False para rellenar los valores ausentes. Para la columna operator_id, debido a que es información sensible y no tengo forma de consultar al ingeniero de datos sobre la información faltante, rellenaré los valores ausentes con 000000.

# %%
# Revisar valores ausentes en cada dataset
print("Valores nulos totales para clients_data: \n", clients_data.isna().sum())
print("\n")
print("Valores nulos totales para telecom_data: \n", telecom_data.isna().sum())

# Se usa el metodo fillna para rellenar valores ausentes
clients_data['internal'] = clients_data['internal'].fillna(False).infer_objects(copy=False)
clients_data['operator_id'] = clients_data['operator_id'].fillna(000000)
# Out:
# Valores nulos totales para clients_data:
#  user_id                   0
# date                      0
# direction                 0
# internal                110
# operator_id            7456
# is_missed_call            0
# calls_count               0
# call_duration             0
# total_call_duration       0
# dtype: int64
#
#
# Valores nulos totales para telecom_data:
#  user_id        0
# tariff_plan    0
# date_start     0
# dtype: int64
# C:\Users\cary_\AppData\Local\Temp\ipykernel_3576\350602025.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   clients_data['internal'] = clients_data['internal'].fillna(False).infer_objects(copy=False)

# %%
# Impresión para comprobar que los valores nulos ya no estan
print("\n")
print("\nValores nulos totales para clients_data: \n", clients_data.isna().sum())
# Out:
# Valores nulos totales para clients_data:
#  user_id                0
# date                   0
# direction              0
# internal               0
# operator_id            0
# is_missed_call         0
# calls_count            0
# call_duration          0
# total_call_duration    0
# dtype: int64

# %%
# Impresión de muestra de datos del dataset telecom_clients_us
display(clients_data.head())

print("\n")

# Impresión de muestra de datos del dataset telecom_dataset_us
display(telecom_data.head())
# Out:
#    user_id                       date direction  internal  operator_id  \
# 0   166377  2019-08-04 00:00:00+03:00        in     False          0.0
# 1   166377  2019-08-05 00:00:00+03:00       out      True     880022.0
# 2   166377  2019-08-05 00:00:00+03:00       out      True     880020.0
# 3   166377  2019-08-05 00:00:00+03:00       out      True     880020.0
# 4   166377  2019-08-05 00:00:00+03:00       out     False     880022.0
#
#    is_missed_call  calls_count  call_duration  total_call_duration
# 0            True            2              0                    4
# 1            True            3              0                    5
# 2            True            1              0                    1
# 3           False            1             10                   18
# 4            True            3              0                   25
#    user_id tariff_plan  date_start
# 0   166713           A  2019-08-15
# 1   166901           A  2019-08-23
# ...

# %%
# Función para convertir los tipos datos de ambos datasets y bajar el tamaño de la memoria usada
def downcast_dtypes(df):
    float_cols = df.select_dtypes("float").columns
    int_cols = df.select_dtypes("integer").columns

    df[float_cols] = df[float_cols].apply(pd.to_numeric, downcast="float")
    df[int_cols] = df[int_cols].apply(pd.to_numeric, downcast="integer")

    return df

# Aplicación de la funcion a ambos datasets
print(downcast_dtypes(clients_data))
print("\n")
print(downcast_dtypes(telecom_data))
# Out:
#        user_id                       date direction  internal  operator_id  \
# 0       166377  2019-08-04 00:00:00+03:00        in     False          0.0
# 1       166377  2019-08-05 00:00:00+03:00       out      True     880022.0
# 2       166377  2019-08-05 00:00:00+03:00       out      True     880020.0
# 3       166377  2019-08-05 00:00:00+03:00       out      True     880020.0
# 4       166377  2019-08-05 00:00:00+03:00       out     False     880022.0
# ...        ...                        ...       ...       ...          ...
# 48997   168606  2019-11-10 00:00:00+03:00       out      True     957922.0
# 48998   168606  2019-11-10 00:00:00+03:00       out      True     957922.0
# 48999   168606  2019-11-11 00:00:00+03:00       out      True     957922.0
# 49000   168606  2019-11-15 00:00:00+03:00       out      True     957922.0
# 49001   168606  2019-11-19 00:00:00+03:00        in     False          0.0
#
# ...

# %% [markdown]
# Después de aplicar la función, se puede observar que aún existen algunas columnas que es necesario convertir. En cuanto a los nombres de las columnas, no será necesario hacer cambios ya que todas están en minúsculas, tienen nombres descriptivos y siguen el formato snake case.

# %%
# Impresion de los datasets para revisar nuevamente los tipos de datos 
clients_data.info()
print("\n")
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49002 entries, 0 to 49001
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              49002 non-null  int32
#  1   date                 49002 non-null  object
#  2   direction            49002 non-null  object
#  3   internal             49002 non-null  bool
#  4   operator_id          49002 non-null  float32
#  5   is_missed_call       49002 non-null  bool
#  6   calls_count          49002 non-null  int16
#  7   call_duration        49002 non-null  int32
#  8   total_call_duration  49002 non-null  int32
# dtypes: bool(2), float32(1), int16(1), int32(3), object(2)
# memory usage: 1.7+ MB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      732 non-null    int32
# ...

# %%
# Conversión de tipos de datos

# Se convierte a tipo fecha la columna date_start del dataset telecom_data
telecom_data['date_start'] = pd.to_datetime(telecom_data['date_start'])

# Se convierte a tipo category columna tariff_plan del dataset telecom_data
telecom_data['tariff_plan'] = telecom_data['tariff_plan'].astype('category')

# Se convierte a tipo fecha la columna date_start del dataset clients_data
clients_data['date'] = pd.to_datetime(clients_data['date'])

# Se convierte a tipo bool columna internal del dataset clients_data
clients_data['internal'] = clients_data['internal'].astype('bool')

# Se convierte a tipo int64 columna operator_id del dataset clients_data
clients_data['operator_id'] = clients_data['operator_id'].astype('int64')

# %%
clients_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49002 entries, 0 to 49001
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              49002 non-null  int32
#  1   date                 49002 non-null  datetime64[ns, UTC+03:00]
#  2   direction            49002 non-null  object
#  3   internal             49002 non-null  bool
#  4   operator_id          49002 non-null  int64
#  5   is_missed_call       49002 non-null  bool
#  6   calls_count          49002 non-null  int16
#  7   call_duration        49002 non-null  int32
#  8   total_call_duration  49002 non-null  int32
# dtypes: bool(2), datetime64[ns, UTC+03:00](1), int16(1), int32(3), int64(1), object(1)
# memory usage: 1.9+ MB

# %%
display(clients_data)
# Out:
#        user_id                      date direction  internal  operator_id  \
# 0       166377 2019-08-04 00:00:00+03:00        in     False            0
# 1       166377 2019-08-05 00:00:00+03:00       out      True       880022
# 2       166377 2019-08-05 00:00:00+03:00       out      True       880020
# 3       166377 2019-08-05 00:00:00+03:00       out      True       880020
# 4       166377 2019-08-05 00:00:00+03:00       out     False       880022
# ...        ...                       ...       ...       ...          ...
# 48997   168606 2019-11-10 00:00:00+03:00       out      True       957922
# 48998   168606 2019-11-10 00:00:00+03:00       out      True       957922
# 48999   168606 2019-11-11 00:00:00+03:00       out      True       957922
# 49000   168606 2019-11-15 00:00:00+03:00       out      True       957922
# 49001   168606 2019-11-19 00:00:00+03:00        in     False            0
#
#        is_missed_call  calls_count  call_duration  total_call_duration
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Se realiza un preprocesamiento exhaustivo de los datos, incluyendo la limpieza de valores duplicados y nulos, y la optimización de tipos de datos. Esto es fundamental para asegurar la calidad del análisis posterior.
#
# </div> <div class="alert alert-block alert-warning"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Aunque el preprocesamiento es robusto, sería útil documentar más los pasos de transformación, especialmente las decisiones como rellenar valores nulos con valores específicos (por ejemplo, 000000). Una breve explicación de por qué se eligieron esos valores fortalecería la transparencia del análisis.
#
# </div>

# %% [markdown]
# # 4. Proponer hipótesis
#
# Hipótesis: Relación entre el Número de Llamadas Perdidas y la Eficacia del Operador
#
# Hipótesis Nula: No existe una relación significativa entre la cantidad de llamadas entrantes perdidas y la eficacia del operador.
#
# Hipótesis Alternativa: Existe una relación significativa entre la cantidad de llamadas entrantes perdidas y la eficacia del operador.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - La hipótesis está bien planteada, y se proporciona tanto la hipótesis nula como la alternativa. Esto demuestra una comprensión clara del enfoque estadístico. Continúa estructurando las hipótesis de esta manera en futuros análisis.

# %% [markdown]
# # 5. Análisis exploratorio de datos

# %% [markdown]
# ### Plan de acción para llegar al objetivo de identificar a los operadores ineficaces
# 1. Analizar la relación entre número de llamadas, duración de llamadas, llamadas perdidas para cada operador.
# 2. Identificar la relacion entre el numero de llamadas y la duracion de la llamada.
# 3. Comparar el tiempo de duracion de las llamadas para cada operador.
# 4. Crear gráficos y visualizaciones para identificar patrones y tendencias en las llamadas de los operadores.
# 5. Determinar las métricas clave para definir la ineficacia de los operadores (por ejemplo, llamadas perdidas, tiempo de espera, número de llamadas salientes)
# 6. Identificar y clasificar a los operadores ineficaces según las métricas definidas.
# 7. Determinar las pruebas estadísticas apropiadas para cada hipótesis.
# 8. Interpretar los resultados de las pruebas estadísticas y sacar conclusiones basadas en los datos.
# 9. Documentar los hallazgos y análisis en un informe claro y detallado.
# 10. Crear presentaciones visuales que resuman los principales hallazgos y recomendaciones.

# %% [markdown]
# ### Analizar la relación entre número de llamadas, duración de llamadas, llamadas perdidas para cada operador.

# %%
# Eliminar filas con operator_id igual a 0 
clients_data_clean = clients_data.loc[clients_data['operator_id'] != 0]

# Agrupar los datos por operador y calcular las métricas
metrics = clients_data_clean.groupby('operator_id').agg(
    total_calls=('calls_count', 'sum'),
    total_call_duration=('call_duration', 'sum'),
    missed_calls=('is_missed_call', 'sum')
).reset_index()


# Crear gráficos de violín para cada métrica
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# Gráfico para el total de llamada
sns.violinplot(x='total_calls', data=metrics, ax=axs[0])
axs[0].set_title('Distribución del Número Total de Llamadas por Operador')

# Gráfico para la duración total de llamadas
sns.violinplot(x='total_call_duration', data=metrics, ax=axs[1])
axs[1].set_title('Distribución de la Duración Total de las Llamadas por Operador')

# Gráfico para el total de llamadas perdidas
sns.violinplot(x='missed_calls', data=metrics, ax=axs[2])
axs[2].set_title('Distribución del Número de Llamadas Perdidas por Operador')

plt.tight_layout()
plt.show()

# %% [markdown]
# Distribución del Número Total de Llamadas por Operador
#
# El gráfico de violín muestra que la mayoría de los operadores tienen un número total de llamadas relativamente bajo, con una concentración alrededor de los valores más pequeños. Sin embargo, hay una cola larga hacia valores más altos, lo que indica que hay algunos operadores que manejan un número significativamente mayor de llamadas.
#
# Distribución de la Duración Total de las Llamadas por Operador
#
# La distribución de la duración total de las llamadas es similar a la del número total de llamadas. La mayoría de los operadores tienen una duración total de llamadas baja, pero hay una cola larga hacia duraciones más largas. Esto sugiere que, aunque la mayoría de los operadores no manejan llamadas muy largas, hay algunos que sí tienen duraciones significativamente mayores.
#
# Distribución del Número de Llamadas Perdidas por Operador
#
# El número de llamadas perdidas también muestra una concentración alrededor de valores bajos, con la mayoría de los operadores teniendo pocas llamadas perdidas. Sin embargo, también hay una cola larga, indicando que algunos operadores tienen un número relativamente alto de llamadas perdidas.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Se presentan análisis visuales claros y descriptivos, como gráficos de violín y de dispersión, que ayudan a interpretar las relaciones entre las métricas. Esto es una buena práctica para comprender los datos antes de realizar pruebas estadísticas.
#
# </div>

# %% [markdown]
# ### Identificar la relacion entre el numero de llamadas y la duracion de la llamada.

# %%
# Agrupar los datos por operador y calcular las métricas
metrics = clients_data_clean.groupby('operator_id').agg(
    total_calls=('calls_count', 'sum'),
    total_call_duration=('call_duration', 'sum')
).reset_index()

# Calcular la correlación
correlation, p_value = pearsonr(metrics['total_calls'], metrics['total_call_duration'])
print(f'Correlación: {correlation}, Valor p: {p_value}')

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(x='total_calls', y='total_call_duration', data=metrics)
plt.title('Relación entre Número Total de Llamadas y Duración Total de Llamadas')
plt.xlabel('Número Total de Llamadas')
plt.ylabel('Duración Total de Llamadas (minutos)')

# Ajustar una línea de regresión
sns.regplot(x='total_calls', y='total_call_duration', data=metrics, scatter=False, color='red')
plt.show()
# Out:
# Correlación: 0.9412309096318842, Valor p: 0.0

# %% [markdown]
# Pendiente Positiva: La línea de regresión tiene una pendiente positiva, lo que indica que hay una relación positiva entre el número total de llamadas y la duración total de las llamadas. Esto significa que, en general, a medida que aumenta el número de llamadas realizadas por un operador, también aumenta la duración total de estas llamadas.
#
# Intervalo de Confianza: El área sombreada alrededor de la línea roja representa el intervalo de confianza. Nos da una idea de la fiabilidad de la línea de regresión. En este caso, el intervalo es relativamente estrecho, lo que sugiere que la relación observada es bastante consistente.
#
# Fuerza de la Relación: Un valor de correlación de 0.9412309096318842 indica una relación muy fuerte entre las dos variables. Esto significa que, en general, a medida que el número total de llamadas aumenta, la duración total de las llamadas también aumenta significativamente.

# %% [markdown]
# ### Comparar el tiempo de duracion de las llamadas para cada operador.

# %%
# Agrupar los datos por operador y calcular la duración promedio de las llamadas
metrics = clients_data_clean.groupby('operator_id').agg(
    avg_call_duration=('call_duration', 'mean')
).reset_index()

# Ordenar los datos por la columna 'avg_call_duration' en orden descendente 
metrics_sorted = metrics.sort_values(by='avg_call_duration', ascending=True).reset_index(drop=True)

# Mostrar los resultados
print(metrics_sorted.head(10))

# Filtrar operadores con duración promedio de llamadas mayor a 0 
metrics_filtered = metrics[metrics['avg_call_duration'] > 0]

# Crear gráfico de líneas
plt.figure(figsize=(10, 6))
plt.plot(metrics_filtered['operator_id'], metrics_filtered['avg_call_duration'], marker='o', linestyle='-', color='b')
plt.title('Duración Promedio de las Llamadas por Operador')
plt.xlabel('ID del Operador')
plt.ylabel('Duración Promedio de Llamadas (minutos)')
plt.grid(True)
plt.show()
# Out:
#    operator_id  avg_call_duration
# 0       945074                0.0
# 1       905308                0.0
# 2       958458                0.0
# 3       919418                0.0
# 4       936296                0.0
# 5       945898                0.0
# 6       924572                0.0
# 7       937872                0.0
# 8       899076                0.0
# 9       960674                0.0

# %% [markdown]
# La mayoría de los operadores tienen una duración promedio de llamadas relativamente baja, con muchos puntos concentrados por debajo de los 2,000 minutos.
#
# Sin embargo, hay varios valores atípicos (outliers) donde la duración promedio de las llamadas supera los 10,000 minutos. Estos operadores tienen duraciones de llamadas significativamente más largas en comparación con los demás.
#
# Los operadores con duraciones promedio de llamadas superiores a 10,000 minutos se destacan claramente en el gráfico. Estos valores atípicos pueden ser indicativos de varios factores, como una mayor carga de trabajo, llamadas más complejas o posibles ineficiencias operativas.
#
# Los operadores con duraciones promedio de llamadas muy altas pueden estar manejando consultas más complicadas o tener una mayor carga de trabajo, lo que resulta en tiempos de llamada más largos.También puede sugerir que algunos operadores son menos eficientes, lo que podría ser una área para mejorar.
#
# Es posible que ciertos operadores tengan patrones de uso distintos que los llevan a tener duraciones de llamadas significativamente más largas.

# %% [markdown]
# ### Determinar las métricas clave para definir la ineficacia de los operadores (llamadas perdidas, tiempo de espera, número de llamadas entrantes y salientes)

# %%
# Calcular la cantidad de llamadas perdidas
llamadas_perdidas = clients_data_clean[clients_data_clean['is_missed_call'] == True].groupby('operator_id')['calls_count'].sum().reset_index()
llamadas_perdidas.rename(columns={'calls_count': 'llamadas_perdidas'}, inplace=True)

# Calcular el tiempo de espera promedio para llamadas entrantes
clients_data_clean['tiempo_espera'] = clients_data_clean['total_call_duration'] - clients_data_clean['call_duration']
tiempo_espera_promedio = clients_data_clean[clients_data_clean['direction'] == 'in'].groupby('operator_id')['tiempo_espera'].mean().reset_index()
tiempo_espera_promedio.rename(columns={'tiempo_espera': 'tiempo_espera_promedio'}, inplace=True)

# Calcular la cantidad de llamadas entrantes y salientes
llamadas_entrantes = clients_data_clean[clients_data_clean['direction'] == 'in'].groupby('operator_id')['calls_count'].sum().reset_index()
llamadas_entrantes.rename(columns={'calls_count': 'llamadas_entrantes'}, inplace=True)

llamadas_salientes = clients_data_clean[clients_data_clean['direction'] == 'out'].groupby('operator_id')['calls_count'].sum().reset_index()
llamadas_salientes.rename(columns={'calls_count': 'llamadas_salientes'}, inplace=True)

# Combinar todas las métricas en un solo dataframe
metricas = llamadas_perdidas.merge(tiempo_espera_promedio, on='operator_id', how='outer')
metricas = metricas.merge(llamadas_entrantes, on='operator_id', how='outer')
metricas = metricas.merge(llamadas_salientes, on='operator_id', how='outer')

# Rellenar valores NaN con 0
metricas.fillna(0, inplace=True)

# Lista de columnas y sus respectivos títulos y etiquetas
columns = [
    ('llamadas_perdidas', 'Distribución de llamadas perdidas por operador', 'Llamadas perdidas'),
    ('tiempo_espera_promedio', 'Distribución del tiempo de espera de llamadas por operador', 'Tiempo de Espera Promedio'),
    ('llamadas_entrantes', 'Distribución de llamadas entrantes por operador', 'Llamadas entrantes'),
    ('llamadas_salientes', 'Distribución de llamadas salientes por operador', 'Llamadas salientes')
]

# Ciclo for para generar los gráficos
for column, title, ylabel in columns:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='operator_id', y=column, data=metricas, alpha=0.5)
    plt.xlabel('Operador ID')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.xticks(rotation=45)  # Rotar etiquetas del eje x si es necesario para mejor legibilidad
    plt.show()
# Out:
# C:\Users\cary_\AppData\Local\Temp\ipykernel_3576\3280260023.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clients_data_clean['tiempo_espera'] = clients_data_clean['total_call_duration'] - clients_data_clean['call_duration']

# %% [markdown]
# Distribución de llamadas perdidas por operador: La mayoría de los operadores tienen un número bajo de llamadas perdidas. Sin embargo, hay algunos operadores con un número significativamente alto de llamadas perdidas, lo que indica problemas en su desempeño. Estos operadores pueden necesitar entrenamiento adicional o soporte para mejorar su eficiencia.
#
# Distribución del Tiempo de Espera de Llamadas por Operador: Un punto en el gráfico representa un operador específico y su tiempo de espera promedio. Si un operador tiene un tiempo de espera promedio alto (puntos más arriba en el eje Y), esto sugiere que las llamadas no están siendo atendidas de manera eficiente, lo cual puede afectar negativamente la experiencia del cliente.
#
# Distribución de Llamadas Entrantes por Operador: En este gráfico, podemos ver la distribución del volumen de llamadas entrantes entre los operadores. Si algunos operadores manejan muchas más llamadas entrantes que otros, podría haber un desequilibrio en la asignación de las llamadas. Esto podría indicar que algunos operadores están sobrecargados, mientras que otros están subutilizados. Un ajuste en la distribución de las llamadas entrantes podría mejorar la eficiencia general del equipo.
#
# Distribución de Llamadas Salientes por Operador: La mayoría de los puntos están cerca de la parte inferior del eje Y, indicando un número bajo de llamadas salientes para la mayoría de los operadores. Sin embargo, hay algunos operadores que realizan un número significativamente alto de llamadas salientes, lo que sugiere una variabilidad en la carga de trabajo asignada.

# %% [markdown]
# ### Identificar y clasificar a los operadores ineficaces según las métricas definidas.

# %%
# Definir umbrales para considerar a un operador como ineficaz
umbral_llamadas_perdidas = 50
umbral_tiempo_espera_promedio = 5  # en minutos
umbral_llamadas_entrantes = 10
umbral_llamadas_salientes = 10


def es_ineficaz(row):
    if (row['llamadas_perdidas'] > umbral_llamadas_perdidas or
        row['tiempo_espera_promedio'] > umbral_tiempo_espera_promedio or
        row['llamadas_entrantes'] < umbral_llamadas_entrantes or
        row['llamadas_salientes'] < umbral_llamadas_salientes):
        return True
    else:
        return False

metricas['ineficaz'] = metricas.apply(es_ineficaz, axis=1)

operadores_ineficaces = metricas[metricas['ineficaz'] == True]

print("Operadores Ineficaces:")
print(operadores_ineficaces)
# Out:
# Operadores Ineficaces:
#       operator_id  llamadas_perdidas  tiempo_espera_promedio  \
# 0          879896              251.0               27.333333
# 1          879898             2360.0               29.473684
# 2          880020               22.0                7.714286
# 3          880022              105.0               14.000000
# 4          880026              648.0                7.944444
# ...           ...                ...                     ...
# 1087       972410               37.0                0.000000
# 1088       972412               25.0               25.000000
# 1089       972460               28.0                4.000000
# 1090       973120                2.0                0.000000
# 1091       973286                0.0               88.000000
#
#       llamadas_entrantes  llamadas_salientes  ineficaz
# 0                   58.0               872.0      True
# 1                  104.0              7209.0      True
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - La identificación de métricas clave como llamadas perdidas y tiempo de espera es fundamental para el análisis. La visualización de estas métricas refuerza las conclusiones y permite identificar tendencias relevantes.
#
# </div>

# %% [markdown]
# ### Determinar las pruebas estadísticas apropiadas para cada hipótesis.

# %% [markdown]
# Hipótesis Nula: No existe una relación significativa entre la cantidad de llamadas entrantes perdidas y la eficacia del operador.
#
# Hipótesis Alternativa: Existe una relación significativa entre la cantidad de llamadas entrantes perdidas y la eficacia del operador.

# %%
# Crear grupos
eficaces = metricas[metricas['ineficaz'] == False]
ineficaces = metricas[metricas['ineficaz'] == True]

alpha = 0.05

# Comparar las llamadas perdidas entre operadores eficaces e ineficaces
result = t_stat, p_value = ttest_ind(eficaces['llamadas_perdidas'], ineficaces['llamadas_perdidas'])

print(f'Prueba t de dos muestras independientes para llamadas perdidas:')
print(f'p-value: {p_value}')

if result.pvalue < alpha:
    print("\nRechazamos la hipótesis nula")
else:
    print("\nNo podemos rechazar la hipótesis nula")
# Out:
# Prueba t de dos muestras independientes para llamadas perdidas:
# p-value: 0.8537085429584299
#
# No podemos rechazar la hipótesis nula

# %%
metricas_a_comparar = ['llamadas_perdidas', 'tiempo_espera_promedio', 'llamadas_entrantes', 'llamadas_salientes']

for metrica in metricas_a_comparar:
    t_stat, p_value = ttest_ind(eficaces[metrica], ineficaces[metrica])
    print(f'\nPrueba t de dos muestras independientes para {metrica}:')
    print(f't-statistic: {t_stat}')
    print(f'p-value: {p_value}')
# Out:
# Prueba t de dos muestras independientes para llamadas_perdidas:
# t-statistic: -0.18443242306692506
# p-value: 0.8537085429584299
#
# Prueba t de dos muestras independientes para tiempo_espera_promedio:
# t-statistic: -0.45061240461590174
# p-value: 0.652358541560913
#
# Prueba t de dos muestras independientes para llamadas_entrantes:
# t-statistic: -0.07259369512206403
# p-value: 0.942142762101327
#
# Prueba t de dos muestras independientes para llamadas_salientes:
# t-statistic: -0.18801223389710234
# p-value: 0.8509020553990504

# %% [markdown]
# Dado que el p-value es mucho mayor que 0.05, no podemos rechazar la hipótesis nula. Esto significa que, según los datos proporcionados, no hay una diferencia significativa en las llamadas perdidas entre los operadores eficaces e ineficaces. En otras palabras, los resultados sugieren que la cantidad de llamadas perdidas no está relacionada significativamente con la eficacia del operador en este contexto.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Las pruebas estadísticas están bien ejecutadas, y los resultados se interpretan correctamente. Esto demuestra un buen manejo de las herramientas estadísticas y su aplicación en el contexto del proyecto.
#
# </div>

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# Resultados de las Pruebas Estadísticas
# Se realizaron pruebas t de dos muestras independientes para comparar las métricas entre operadores eficaces e ineficaces. Los resultados obtenidos fueron los siguientes:
#
# Llamadas Perdidas:
#
# t-statistic: -0.1844
#
# p-value: 0.8537
#
# No se encontró una diferencia significativa en la cantidad de llamadas perdidas entre operadores eficaces e ineficaces.
#
# Los valores p obtenidos en todas las pruebas fueron mayores que el nivel de significancia de 0.05, lo que implica que no hay evidencia suficiente para rechazar la hipótesis nula en ninguno de los casos. Por lo tanto, no se encontró una relación significativa entre las métricas evaluadas (llamadas perdidas, tiempo de espera promedio, llamadas entrantes y salientes) y la eficacia del operador.
#
# Implicaciones
# Estos resultados sugieren que, según los datos disponibles, las métricas evaluadas no son determinantes para clasificar a los operadores como eficaces o ineficaces. Esto implica que otras variables podrían estar influyendo en la eficacia del operador y que sería necesario considerar métricas adicionales o diferentes enfoques para evaluar el rendimiento de los operadores.
#
# Recomendaciones
# Explorar Otras Métricas: Considerar métricas adicionales como la tasa de resolución en la primera llamada, la satisfacción del cliente, o el feedback de los clientes para obtener una visión más completa de la eficacia del operador.
#
# Análisis Adicional: Realizar análisis más detallados, como regresiones múltiples, para identificar factores combinados que puedan influir en la eficacia del operador.
#
# Revisión de Datos: Asegurarse de que los datos utilizados sean completos y precisos para evitar cualquier sesgo o error que pueda afectar los resultados del análisis.
#
# En resumen, aunque no se encontró una relación significativa entre las métricas evaluadas y la eficacia del operador, este análisis proporciona una base sólida para futuras investigaciones y mejoras en la evaluación del rendimiento de los operadores.

# %% [markdown]
# # **Comentario General del Revisor**
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# ¡Felicidades! Tu proyecto está **aprobado**. Has demostrado un excelente manejo de las herramientas de análisis de datos, desde el preprocesamiento hasta las pruebas estadísticas. A continuación, destaco los puntos positivos y algunas áreas interesantes para seguir investigando:
#
# #### Puntos Positivos:
# - **Preprocesamiento de datos:** Excelente limpieza y optimización de los datasets.
# - **Visualización y análisis gráfico:** Gráficos claros y bien interpretados que refuerzan las conclusiones.
# - **Pruebas estadísticas:** Aplicación correcta de técnicas estadísticas para evaluar hipótesis.
#
# #### Áreas para Seguir Investigando:
# - **Definición de umbrales:** Justificar mejor los valores elegidos para clasificar operadores ineficaces.
# - **Exploración de variables adicionales:** Considerar nuevas métricas que puedan influir en la eficacia del operador.
# - **Validación cruzada:** Implementar métodos para validar las conclusiones y mejorar la robustez del análisis.
#
# ¡Sigue así, estás haciendo un gran trabajo! 💪🚀😊
# </div>

# %% [markdown]
# ### Fuentes de información:
#
# Mediante esta fuente de información logre contestar la parte de:
# Identificar la relación entre el número de llamadas y la duración de la llamada. Esto me ayudó a entender la relación entre las variables.
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.pearsonr.html
#
# En esta fuente de información encontre lo necesario para llevar a cabo la prueba de las hipótesis
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html
#
# A través de esta fuente encontré información sobre cómo realizar gráficos para representar los resultados de los cálculos.
# https://seaborn.pydata.org/tutorial/introduction.html
#
# En este enlace encontré la información para realizar gráficos para las métricas del estudio.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html
